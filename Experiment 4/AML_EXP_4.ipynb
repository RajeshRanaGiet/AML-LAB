# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshRanaGiet/AML-LAB/blob/main/Experiment%204/AML_EXP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def predict(x,w,b):
  return w*x+b

def compute_cost(y, y_pred):
  return np.sum((y-y_pred)**2)/n # cost function for actual gradient descent

def gradient(x,y,y_pred):
  dw = (np.sum(x*(y-y_pred)*-2))/n
  db = (np.sum(y-y_pred)*-2)/n
  return dw, db

def parameter_update(w,b,dw,db,alpha):
  w = w - alpha*dw
  b = b - alpha*db
  return w,b

x = np.array([1,2,3], dtype=float)
y = np.array([2,3,4], dtype=float)

n = len(x)
print("Input x : ", x)
print("Actual y : ", y)
print("Number of samples : ", n)

w = 0.0
b = 0.0
alpha = 0.1
itterations = 3
print("Initial weight (w) : ", w)
print("Initial bias (b) : ", b)
print("Learning rate : ", alpha)

y_pred = predict(x,w,b)
print("Predictions : ", y_pred)


cost = compute_cost(y,y_pred)
print("\nInitial prediction", y_pred)
print(f"Initial Cost : {cost:.4f}")

costs = []
w_history = []
b_history = []


for i in range(itterations):
  y_pred_current_params = predict(x,w,b)
  dw, db = gradient(x,y,y_pred_current_params)
  w, b = parameter_update(w,b,dw,db,alpha)
  y_pred_after_update = predict(x,w,b)
  cost_after_update = compute_cost(y,y_pred_after_update)

  costs.append(cost_after_update)
  w_history.append(w)
  b_history.append(b)
  print("\n"+"-"*30)
  print(f"Itteration {i+1}")
  print(f"The y_predict (after update) is {np.round(y_pred_after_update, 4)}")
  print(f"The cost (after update) is {cost_after_update:.4f}")
  print(f"Gradients dw: {dw:.4f}, db: {db:.4f}")
  print(f"The updated weight (w) is {w:.4f}")
  print(f"The updated bias (b) is {b:.4f}")


final_w = w_history[-1]
final_b = b_history[-1]
print("\nThe final equation is : ")
print(f"y = {final_w:.4f}x + {final_b:.4f}")
print("The final cost is ", costs[-1])
# Out:
# Input x :  [1. 2. 3.]
# Actual y :  [2. 3. 4.]
# Number of samples :  3
# Initial weight (w) :  0.0
# Initial bias (b) :  0.0
# Learning rate :  0.1
# Predictions :  [0. 0. 0.]
#
# Initial prediction [0. 0. 0.]
# Initial Cost : 9.6667
#
# ------------------------------
# Itteration 1
# The y_predict (after update) is [1.9333 3.2667 4.6   ]
# The cost (after update) is 0.1452
# Gradients dw: -13.3333, db: -6.0000
# The updated weight (w) is 1.3333
# The updated bias (b) is 0.6000
#
# ------------------------------
# Itteration 2
# The y_predict (after update) is [1.7289 2.9111 4.0933]
# The cost (after update) is 0.0300
# Gradients dw: 1.5111, db: 0.5333
# The updated weight (w) is 1.1822
# The updated bias (b) is 0.5467
#
# ------------------------------
# Itteration 3
# The y_predict (after update) is [1.7579 2.9514 4.1449]
# The cost (after update) is 0.0273
# Gradients dw: -0.1126, db: -0.1778
# The updated weight (w) is 1.1935
# The updated bias (b) is 0.5644
#
# The final equation is :
# y = 1.1935x + 0.5644
# The final cost is  0.02731796250571558

# %%
plt.plot(range(itterations), costs)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function VS Iterations')
plt.show()


plt.scatter(x,y, label='Actual Data')
if itterations > 0:
    final_y_pred_for_plot = predict(x, final_w, final_b)
else:
    final_y_pred_for_plot = predict(x, w, b)
plt.plot(x, final_y_pred_for_plot, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# --- Plot 1: Cost Function ---
plt.figure(figsize=(6, 4))
plt.plot(range(itterations), costs, color='#2b5c8f', linewidth=2.5)
plt.xlabel('Iterations', fontweight='bold')
plt.ylabel('Cost', fontweight='bold')
plt.title('Cost Function VS Iterations', fontsize=12, pad=10)
plt.grid(True, linestyle='--', alpha=0.5)  # Subtle background grid
plt.tight_layout()
plt.show()

# --- Plot 2: Linear Regression Fit ---
plt.figure(figsize=(6, 4))

# Set alpha=0.6 to make overlapping points easier to see
plt.scatter(x, y, color='#4c9be8', alpha=0.6, edgecolors='none', label='Actual Data')

if itterations > 0:
    final_y_pred_for_plot = predict(x, final_w, final_b)
else:
    final_y_pred_for_plot = predict(x, w, b)

plt.plot(x, final_y_pred_for_plot, color='#e74c3c', linewidth=2.5, label='Regression Line')
plt.xlabel('x', fontweight='bold')
plt.ylabel('y', fontweight='bold')
plt.title('Linear Regression Fit', fontsize=12, pad=10)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(frameon=True, facecolor='white', framealpha=0.9)
plt.tight_layout()
plt.show()
