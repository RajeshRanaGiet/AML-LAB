# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshRanaGiet/AML-LAB/blob/main/Experiment%204/AML_EXP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3], dtype=float)
y = np.array([2,3,4], dtype=float)

n = len(x)
print("Input x : ", x)
print("Actual y : ", y)
print("Number of samples : ", n)

w = 0.0
b = 0.0
alpha = 0.1
itterations = 2
print("Initial weight (w) : ", w)
print("Initial bias (b) : ", b)
print("Learning rate : ", alpha)

def predict(x,w,b):
  return w*x+b

y_pred = predict(x,w,b)
print("Predictions : ", y_pred)

def compute_cost(y, y_pred):
  return np.sum((y-y_pred)**2)/n # cost function for actual gradient descent

y_pred = predict(x,w,b)
cost = compute_cost(y,y_pred)
print("\nInitial prediction", y_pred)
print("Initial Cost : ", cost)

def gradient(x,y,y_pred):
  dw = (np.sum(x*(y_pred-y))*2)/n
  db = (np.sum(y_pred-y)*2)/n
  return dw, db

def parameter_update(w,b,dw,db,alpha):
  w = w - alpha*dw
  b = b - alpha*db
  return w,b

costs = []
w_history = []
b_history = []


for i in range(itterations):
  y_pred_current_params = predict(x,w,b)
  dw, db = gradient(x,y,y_pred_current_params)
  w, b = parameter_update(w,b,dw,db,alpha)
  y_pred_after_update = predict(x,w,b)
  cost_after_update = compute_cost(y,y_pred_after_update)

  costs.append(cost_after_update)
  w_history.append(w)
  b_history.append(b)

  print(f"\nItteration {i}")
  print("The y_predict (after update) is ", y_pred_after_update)
  print("The cost (after update) is ", cost_after_update)
  print(f"Gradients dw: {dw}, db: {db}")
  print("The updated weight (w) is ", w)
  print("The updated bias (b) is ", b)

final_w = w_history[-1]
final_b = b_history[-1]
print("\nThe final equation is : ")
print(f"y = {final_w}x + {final_b}")
# Out:
# Input x :  [1. 2. 3.]
# Actual y :  [2. 3. 4.]
# Number of samples :  3
# Initial weight (w) :  0.0
# Initial bias (b) :  0.0
# Learning rate :  0.1
# Predictions :  [0. 0. 0.]
#
# Initial prediction [0. 0. 0.]
# Initial Cost :  9.666666666666666
#
# Itteration 0
# The y_predict (after update) is  [1.93333333 3.26666667 4.6       ]
# The cost (after update) is  0.1451851851851851
# Gradients dw: -13.333333333333334, db: -6.0
# The updated weight (w) is  1.3333333333333335
# The updated bias (b) is  0.6000000000000001
#
# Itteration 1
# The y_predict (after update) is  [1.72888889 2.91111111 4.09333333]
# The cost (after update) is  0.030037860082304486
# Gradients dw: 1.511111111111111, db: 0.5333333333333335
# The updated weight (w) is  1.1822222222222223
# The updated bias (b) is  0.5466666666666667
#
# The final equation is :
# y = 1.1822222222222223x + 0.5466666666666667

# %%
plt.plot(range(itterations), costs)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function VS Iterations')
plt.show()


plt.scatter(x,y, label='Actual Data')
if itterations > 0:
    final_y_pred_for_plot = predict(x, final_w, final_b)
else:
    final_y_pred_for_plot = predict(x, w, b)
plt.plot(x, final_y_pred_for_plot, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(0-0.1*-13.33)
# Out:
# 1.3330000000000002

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(itterations), costs)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function Over Iterations')

plt.subplot(1, 2, 2)
plt.scatter(x,y, label='Actual Data')
plt.plot(x,y_pred, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3], dtype=float)
y = np.array([2,3,4], dtype=float)

n = len(x)
print("Input x : ", x)
print("Actual y : ", y)
print("Number of samples : ", n)

w = 0.0
b = 0.0
alpha = 0.1
itterations = 2
print("Initial weight (w) : ", w)
print("Initial bias (b) : ", b)
print("Learning rate : ", alpha)

def predict(x,w,b):
  return w*x+b

y_pred = predict(x,w,b)
print("Predictions : ", y_pred)

def compute_cost(y, y_pred):
  return np.sum((y-y_pred)**2)/n # cost function for actual gradient descent

y_pred = predict(x,w,b)
cost = compute_cost(y,y_pred)
print("\nInitial prediction", y_pred)
print("Initial Cost : ", cost)

def gradient(x,y,y_pred):
  dw = (np.sum(x*(y-y_pred))*-2)/n
  db = (np.sum(y-y_pred)*-2)/n
  return dw, db

def parameter_update(w,b,dw,db,alpha):
  w = w - alpha*dw
  b = b - alpha*db
  return w,b

dw, db = gradient(x,y,y_pred)
w, b = parameter_update(w,b,dw,db,alpha)
print("\nUpdated weight (w) : ", w)
print("Updated bias (b) : ", b)

for i in range(itterations):
  y_pred = predict(x,w,b)
  dw, db = gradient(x,y,y_pred)
  w, b = parameter_update(w,b,dw,db,alpha)
  cost = compute_cost(y,y_pred)
  print(f"\nItteration {i}")
  print("The y_predict is ", y_pred)
  print("The cost is ", cost)
  print("The updated weight (w) is ", w)
  print("The updated bias (b) is ", b)

plt.scatter(x,y)
plt.plot(x,y_pred)
plt.show()
